# %% [markdown]
# <a href="https://colab.research.google.com/github/amargauge26/dataseinceeureka/blob/main/ARMarmapporio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df  = pd.read_excel("/content/online_retail_II.xlsx")
df.head(5)
# Out:
#   Invoice StockCode                          Description  ...  Price Customer ID         Country
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS  ...   6.95     13085.0  United Kingdom
# 1  489434    79323P                   PINK CHERRY LIGHTS  ...   6.75     13085.0  United Kingdom
# 2  489434    79323W                  WHITE CHERRY LIGHTS  ...   6.75     13085.0  United Kingdom
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE   ...   2.10     13085.0  United Kingdom
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX  ...   1.25     13085.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
basket = (df[df['Country'] == 'France']
          .groupby(['Invoice', 'Description'])['Quantity']
          .sum()
          .unstack()
          .reset_index()
          .fillna(0)
          .set_index('Invoice'))
basket
# Out:
# Description   FLAMINGO LIGHTS  ...  ZINC WILLIE WINKIE  CANDLE STICK
# Invoice                        ...
# 489439                    0.0  ...                               0.0
# 489557                    0.0  ...                               0.0
# 489883                    0.0  ...                               0.0
# 490139                    0.0  ...                               0.0
# 490152                    0.0  ...                               0.0
# ...                       ...  ...                               ...
# C531455                   0.0  ...                               0.0
# C532390                   0.0  ...                               0.0
# C533304                   0.0  ...                               0.0
# C534372                   0.0  ...                               0.0
# C537893                   0.0  ...                               0.0
#
# [297 rows x 1428 columns]

# %%
def encode_units(x):
  if x<=0:
    return 0
  if x>=1:
    return 1
basket_sets = basket.applymap(encode_units)
basket_sets.drop("POSTAGE",inplace=True,axis=1)
basket_sets
# Out:
# <ipython-input-7-7865deecf6cb>:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket.applymap(encode_units)
# Description   FLAMINGO LIGHTS  ...  ZINC WILLIE WINKIE  CANDLE STICK
# Invoice                        ...
# 489439                      0  ...                                 0
# 489557                      0  ...                                 0
# 489883                      0  ...                                 0
# 490139                      0  ...                                 0
# 490152                      0  ...                                 0
# ...                       ...  ...                               ...
# C531455                     0  ...                                 0
# C532390                     0  ...                                 0
# C533304                     0  ...                                 0
# C534372                     0  ...                                 0
# ...

# %%
freq_items = apriori(basket_sets,min_support=0.07,use_colnames=True)
rules = association_rules(freq_items,metric="lift",min_threshold=1)
rules.head()
# Out:
#                            antecedents  ... zhangs_metric
# 0           (CIRCUS PARADE LUNCH BOX )  ...      0.945477
# 1                (SPACEBOY LUNCH BOX )  ...      0.959748
# 2  (LUNCH BOX WITH CUTLERY RETROSPOT )  ...      0.960243
# 3  (STRAWBERRY LUNCH BOX WITH CUTLERY)  ...      0.938169
# 4     (PLASTERS IN TIN CIRCUS PARADE )  ...      0.958774
#
# [5 rows x 10 columns]

# %%
rules[(rules["lift"]>=6 )& rules['confidence']>=0.8]
# Out:
#                         antecedents                      consequents  ...  conviction  zhangs_metric
# 0        (CIRCUS PARADE LUNCH BOX )            (SPACEBOY LUNCH BOX )  ...    3.569024       0.945477
# 1             (SPACEBOY LUNCH BOX )       (CIRCUS PARADE LUNCH BOX )  ...    2.634833       0.959748
# 12  (SET/6 RED SPOTTY PAPER PLATES)    (SET/6 RED SPOTTY PAPER CUPS)  ...    5.175084       0.963930
# 13    (SET/6 RED SPOTTY PAPER CUPS)  (SET/6 RED SPOTTY PAPER PLATES)  ...    3.609428       0.974843
#
# [4 rows x 10 columns]
